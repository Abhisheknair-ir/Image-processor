# %%
from collections import Counter
from PIL import Image
from sklearn.cluster import KMeans
import numpy as np

def extract_colors(folder_path):

    colors_dict = {}
    
    # Scanning the files in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(".jpg") or filename.endswith(".png"):
            # Open the image
            image_path = os.path.join(folder_path, filename)
            image = Image.open(image_path)
            
            # Resize the image to a smaller size for faster processing
            image = image.resize((150, 150), resample=Image.BILINEAR)
            
            # Convert the image to a numpy array
            pixels = np.array(image)
            
            # Flatten the array and find the dominant colors using K-Means
            pixel_values = pixels.reshape(-1, 3)
            kmeans = KMeans(n_clusters=5, random_state=0).fit(pixel_values)
            dominant_colors = [tuple(color.astype(int)) for color in kmeans.cluster_centers_]
            
            # Add the dominant colors to the dictionary
            colors_dict[filename] = dominant_colors
    
    return colors_dict

folder_path = "D:/TAG/V01/Trial_DataSet/Model01/Output"
colors_dict = extract_colors(folder_path)

# Print the dominant colors for each image
for filename, colors in colors_dict.items():
    print(f"Dominant colors in {filename}: {colors}")
# Out:
# Dominant colors in processed_000d31f6-44b5-4758-8d86-c4fcfb234392.jpg: [(216, 81, 160), (1, 1, 1), (80, 162, 246), (250, 220, 82), (176, 248, 223)]
# Dominant colors in processed_00a1b7a8-217d-45bf-93a8-86db0bdf9d9d.jpg: [(56, 58, 65), (1, 0, 1), (252, 51, 51), (59, 252, 52), (53, 60, 252)]
# Dominant colors in processed_00ac820c-c5f3-48c1-a4b3-a8b66b06a1aa.jpg: [(172, 164, 148), (0, 0, 0), (241, 205, 194), (191, 172, 253), (174, 253, 201)]
# Dominant colors in processed_00b8048d-635e-4e56-b182-071fb24eea32.jpg: [(63, 62, 61), (60, 252, 62), (252, 62, 62), (61, 60, 252), (1, 1, 1)]
# Dominant colors in processed_00bede7c-eae4-4ee9-a1ac-1721b3f94c54.jpg: [(49, 51, 59), (59, 249, 47), (249, 47, 49), (49, 58, 250), (0, 0, 0)]
# Dominant colors in processed_00d94e21-5891-492e-be0e-792e7338c077.jpg: [(145, 116, 116), (0, 0, 0), (172, 168, 253), (167, 253, 174), (228, 187, 183)]
# Dominant colors in processed_00d9cc6e-2564-4813-9d68-4bc4d562107b.jpg: [(81, 45, 142), (0, 0, 0), (158, 249, 94), (45, 151, 252), (252, 81, 42)]
# Dominant colors in processed_00e745c9-97d9-429d-8c3f-d3db7a2d2991.jpg: [(158, 59, 116), (1, 1, 1), (56, 116, 252), (116, 251, 161), (253, 161, 56)]
# Dominant colors in processed_00f4bb77-5cbd-4c81-98b5-42647b8d0c64.jpg: [(87, 87, 95), (0, 0, 0), (250, 97, 96), (104, 253, 96), (100, 109, 247)]
# Dominant colors in processed_00f6e504-7c27-438e-a5d7-bc65e557bb2b.jpg: [(51, 50, 45), (0, 0, 0), (41, 36, 251), (251, 43, 42), (37, 251, 43)]
# Dominant colors in processed_00fc9948-363d-41dd-98c2-e6be140f543f.jpg: [(86, 45, 30), (27, 252, 93), (44, 27, 251), (0, 0, 0), (251, 93, 45)]
# Dominant colors in processed_0a18630c-527b-4d56-9a98-8a0cfe341ab5.jpg: [(186, 204, 237), (0, 0, 0), (253, 170, 187), (205, 253, 170), (124, 131, 148)]
# Dominant colors in processed_0a1955a3-c4c5-4141-8a72-afbcf92d0dfa.jpg: [(162, 28, 64), (65, 251, 165), (0, 0, 0), (25, 65, 250), (252, 166, 25)]
# Dominant colors in processed_0a2668d3-e42a-4f46-bb7f-01cc409c1839.jpg: [(132, 141, 146), (1, 1, 1), (253, 137, 148), (157, 253, 138), (149, 158, 249)]
# Dominant colors in processed_0a30baec-1938-47c5-b495-68a51701b43d.jpg: [(216, 217, 216), (2, 2, 2), (244, 32, 31), (34, 246, 30), (30, 34, 244)]
# Dominant colors in processed_0a3e62e3-fac5-4648-9da2-f6bc4074ee31.jpg: [(92, 156, 205), (5, 5, 5), (219, 37, 120), (164, 220, 35), (58, 67, 72)]
# Dominant colors in processed_0a5d2669-3f7f-4350-9f1b-42204b0a9706.jpg: [(3, 3, 3), (102, 250, 59), (247, 66, 71), (146, 179, 231), (59, 78, 190)]
# Dominant colors in processed_0a671f9d-d105-4ec9-8642-f4f228f8a90f.jpg: [(192, 36, 59), (1, 1, 1), (34, 59, 247), (251, 197, 34), (59, 250, 195)]
# Dominant colors in processed_0a69bc16-6adc-4563-8aa1-958c32f66524.jpg: [(156, 162, 152), (0, 0, 0), (169, 157, 253), (158, 253, 163), (253, 163, 169)]
# Dominant colors in processed_0a69db60-c052-4b9a-a90d-e53120d091d5.jpg: [(128, 134, 123), (0, 0, 0), (181, 157, 251), (158, 251, 193), (232, 195, 178)]
# Dominant colors in processed_0a77dbed-06fb-4ba7-b1e3-24f3a41498bc.jpg: [(177, 154, 132), (1, 1, 1), (158, 136, 252), (135, 252, 180), (253, 182, 160)]
# Dominant colors in processed_0a7e5fe0-d592-40e6-b9b8-75aac9a2d685.jpg: [(219, 50, 51), (1, 1, 1), (49, 53, 249), (52, 251, 220), (251, 222, 50)]
# Dominant colors in processed_0a85a584-cb49-4795-b2f1-7eebbf09399a.jpg: [(168, 170, 167), (1, 1, 1), (253, 174, 175), (175, 173, 253), (173, 253, 174)]
# Dominant colors in processed_0a86d893-93f1-4a52-8c42-07bb9f439833.jpg: [(0, 0, 0), (252, 26, 28), (31, 252, 26), (28, 31, 252), (31, 34, 36)]
# Dominant colors in processed_0a904aee-7ee6-41db-bb7f-97e991c6a994.jpg: [(116, 112, 252), (2, 1, 2), (182, 118, 109), (113, 251, 131), (216, 204, 202)]
# Dominant colors in processed_0aa095c3-9d4d-4416-8788-82655af859a8.jpg: [(197, 199, 229), (1, 1, 1), (253, 194, 196), (139, 140, 140), (197, 253, 194)]
# Dominant colors in processed_0ab26941-211e-44d7-a62a-20207fa7a3e0.jpg: [(139, 140, 138), (0, 0, 0), (152, 150, 253), (149, 253, 151), (248, 155, 156)]
# Dominant colors in processed_0acef3a8-51f3-42ce-8842-10e4898c0a0f.jpg: [(133, 139, 181), (1, 0, 1), (242, 242, 242), (249, 131, 134), (148, 252, 135)]
# Dominant colors in processed_0ad5bfb5-0f2b-4396-8c05-39ca0a9a2960.jpg: [(229, 215, 226), (0, 0, 0), (43, 100, 160), (141, 123, 95), (211, 252, 219)]
# Dominant colors in processed_0ad8629f-2e9f-4591-a661-7489d6d49737.jpg: [(80, 73, 71), (73, 252, 83), (75, 73, 252), (0, 0, 0), (250, 85, 76)]
# Dominant colors in processed_0add1694-17d0-46ec-a9fc-900da252af41.jpg: [(195, 226, 194), (0, 0, 0), (253, 192, 192), (126, 124, 120), (192, 192, 253)]
# Dominant colors in processed_0af4203f-8998-4719-92fe-65c14a6b6093.jpg: [(94, 91, 83), (1, 1, 1), (91, 83, 253), (249, 106, 102), (86, 253, 98)]
# Dominant colors in processed_0b0457d9-32f9-4b34-915d-017e5525d9f6.jpg: [(47, 50, 57), (55, 251, 44), (251, 44, 47), (47, 55, 251), (0, 0, 0)]
# Dominant colors in processed_0b1cc7a6-be78-45e6-be22-2ad00b107328.jpg: [(193, 253, 191), (0, 0, 0), (195, 196, 229), (253, 190, 193), (131, 134, 131)]
# Dominant colors in processed_0b20fabe-a5f2-4549-bbb2-504ee53dc89d.jpg: [(139, 75, 117), (0, 0, 0), (72, 119, 252), (119, 252, 143), (253, 143, 72)]
# Dominant colors in processed_0b546ee0-81f3-4d93-938d-34166d4194d7.jpg: [(33, 48, 68), (68, 252, 29), (252, 29, 46), (0, 0, 0), (46, 69, 252)]
# Dominant colors in processed_0b55a8e8-0087-4c19-8729-b872718ff5ae.jpg: [(7, 7, 7), (185, 187, 171), (44, 46, 251), (247, 46, 40), (40, 251, 44)]
# Dominant colors in processed_0b5f7f85-fa44-4406-91ed-6b730e4b6fa1.jpg: [(135, 145, 156), (1, 1, 1), (253, 150, 161), (175, 253, 150), (165, 178, 241)]
# Dominant colors in processed_0b7dc2e9-a9e9-46ed-b4e2-8b91e1e720b0.jpg: [(87, 193, 89), (197, 200, 202), (4, 3, 4), (76, 78, 252), (252, 78, 78)]
# Dominant colors in processed_0b7f4987-34e4-4c85-9f28-35e04ae78ece.jpg: [(41, 43, 53), (252, 46, 48), (64, 249, 51), (47, 58, 252), (0, 0, 0)]
# Dominant colors in processed_0ba2d892-a1fb-4961-88a8-d77875b9f673.jpg: [(198, 227, 196), (0, 0, 0), (203, 204, 250), (101, 109, 114), (253, 197, 200)]
# Dominant colors in processed_0ba71e2a-4941-4c09-952e-e32895840d34.jpg: [(176, 170, 165), (0, 0, 0), (178, 172, 253), (172, 253, 186), (253, 186, 178)]
# Dominant colors in processed_0bacb2c4-3d90-4835-b23e-aa7c2284d1bc.jpg: [(43, 49, 62), (61, 55, 250), (238, 98, 58), (0, 0, 0), (58, 251, 103)]
# Dominant colors in processed_0bad128f-51d3-4f15-9213-0856d8bac797.jpg: [(69, 128, 139), (0, 0, 0), (144, 253, 68), (252, 68, 132), (134, 145, 253)]
# Dominant colors in processed_0bb100d9-e760-4bc6-8d74-4cdd429d38eb.jpg: [(110, 110, 120), (0, 0, 0), (111, 121, 253), (121, 253, 111), (253, 111, 111)]
# Dominant colors in processed_0bd7a506-9042-4dfc-b061-0a8279c887bb.jpg: [(46, 46, 48), (252, 46, 45), (47, 252, 45), (45, 47, 252), (0, 0, 0)]
# Dominant colors in processed_0bd9bcb2-a108-4aa5-964d-f3a9f814e9c1.jpg: [(51, 34, 41), (43, 252, 56), (35, 43, 252), (252, 58, 37), (0, 0, 0)]
# Dominant colors in processed_0bdfdcd8-8ca7-410b-8e92-d47ff1aa5546.jpg: [(227, 228, 226), (0, 0, 0), (104, 106, 93), (197, 192, 163), (160, 159, 247)]
# Dominant colors in processed_0c024616-1289-4747-91da-71a4aedd4ced.jpg: [(218, 89, 68), (120, 251, 158), (215, 183, 195), (5, 5, 5), (63, 76, 249)]
# Dominant colors in processed_0c224954-0e0f-4caa-82c8-cf9581e89336.jpg: [(45, 46, 47), (0, 0, 0), (49, 251, 45), (251, 45, 46), (46, 48, 252)]
# Dominant colors in processed_0c2eb9ff-7f26-492d-9957-0d845669685f.jpg: [(60, 60, 64), (1, 1, 1), (252, 58, 58), (62, 252, 58), (58, 62, 252)]
# Dominant colors in processed_0c423d7d-d7a3-4a27-a9ce-01133543f246.jpg: [(98, 109, 139), (0, 0, 0), (154, 252, 106), (252, 106, 119), (122, 154, 246)]
# Dominant colors in processed_0c42c400-2c26-471f-93a9-40d00df87e6c.jpg: [(211, 221, 209), (1, 1, 1), (250, 134, 135), (136, 176, 140), (137, 160, 251)]
# Dominant colors in processed_0c4d3d88-9756-4211-83ad-2d6c68ea0043.jpg: [(218, 41, 51), (1, 2, 1), (53, 251, 213), (38, 51, 249), (252, 221, 41)]
# Dominant colors in processed_0c4fe429-cc94-49a1-b6b3-6660957db97b.jpg: [(42, 43, 46), (35, 39, 252), (39, 252, 35), (0, 0, 0), (251, 35, 35)]
# Dominant colors in processed_0c50d57f-6132-4395-a71b-f82176293609.jpg: [(172, 167, 161), (2, 1, 2), (172, 166, 253), (253, 179, 172), (166, 253, 178)]
# Dominant colors in processed_0c6472ac-e3f8-443b-a884-2e60562c35b1.jpg: [(75, 75, 79), (252, 74, 74), (79, 252, 74), (1, 0, 0), (74, 79, 252)]
# Dominant colors in processed_0c6f89cd-30f6-4b44-bda5-0ba8d90e6717.jpg: [(107, 64, 29), (64, 23, 160), (2, 2, 2), (24, 161, 96), (188, 129, 95)]
# Dominant colors in processed_0c7412e7-81eb-40b7-be64-ce9782103529.jpg: [(45, 46, 46), (88, 252, 53), (72, 99, 238), (252, 52, 68), (0, 0, 0)]
# Dominant colors in processed_0c7e73b3-af7e-4b6c-b142-82a3760114c3.jpg: [(174, 169, 253), (1, 1, 1), (230, 211, 215), (164, 151, 142), (181, 253, 183)]
# Dominant colors in processed_0c99f0b4-3a0d-4d24-bfdd-e9e98914892c.jpg: [(195, 152, 157), (1, 0, 1), (151, 252, 141), (164, 151, 252), (58, 58, 59)]
# Dominant colors in processed_0ca7f456-e16e-4afe-ab4e-9639719ec0b5.jpg: [(125, 64, 86), (0, 0, 0), (83, 251, 126), (56, 83, 251), (252, 126, 56)]
# Dominant colors in processed_0cab4de0-5818-4680-a00a-35dbc6e95525.jpg: [(202, 119, 127), (1, 1, 1), (118, 131, 251), (131, 252, 206), (253, 209, 121)]
# Dominant colors in processed_0cb3a527-be77-4ba9-9430-c097a45d4db5.jpg: [(51, 51, 50), (49, 252, 49), (252, 50, 50), (50, 49, 252), (0, 0, 0)]
# Dominant colors in processed_0cb4fc9c-7d38-4f11-95ea-71b61d0ae54c.jpg: [(32, 30, 31), (251, 28, 25), (28, 251, 28), (25, 27, 250), (0, 0, 0)]
# Dominant colors in processed_0cb83705-48f5-42f4-9288-cd7d11cb77c5.jpg: [(110, 103, 91), (1, 1, 1), (156, 154, 229), (141, 252, 149), (252, 149, 145)]
# Dominant colors in processed_0ccc318a-7d69-4d7f-a442-aac1f88bc453.jpg: [(38, 40, 49), (0, 0, 0), (251, 37, 39), (39, 50, 252), (50, 252, 37)]
# Dominant colors in processed_0cd501af-4cce-460d-9431-637bf0d95499.jpg: [(150, 153, 232), (0, 0, 0), (252, 137, 140), (108, 107, 103), (141, 252, 138)]
# Dominant colors in processed_0d047b70-c53a-463d-946f-c8758c2af391.jpg: [(67, 54, 47), (46, 253, 69), (252, 71, 56), (55, 46, 252), (0, 0, 0)]
# Dominant colors in processed_0d0bb91d-01d7-45df-827d-da96bbc44b15.jpg: [(54, 60, 72), (0, 0, 0), (251, 52, 58), (73, 251, 52), (58, 73, 252)]
# Dominant colors in processed_0d0c2308-2c58-4e38-90c1-c893358b5f86.jpg: [(115, 103, 86), (0, 0, 0), (87, 252, 121), (106, 87, 252), (252, 121, 106)]
# Dominant colors in processed_0d1df3d4-ad7f-43f8-9673-90d368f6c853.jpg: [(166, 186, 229), (0, 0, 0), (253, 144, 175), (192, 253, 144), (89, 129, 119)]
# Dominant colors in processed_0d24634d-4daa-41bc-8acf-61b8382e0419.jpg: [(178, 179, 232), (1, 1, 1), (136, 140, 141), (253, 167, 171), (171, 253, 167)]
# Dominant colors in processed_0d293c69-ba4f-4ffc-b6b9-fa05316a02c5.jpg: [(68, 74, 86), (85, 253, 65), (253, 65, 71), (71, 85, 253), (1, 1, 1)]
# Dominant colors in processed_0d3b1b5a-3d8d-406f-b953-5b506b8f5665.jpg: [(71, 69, 73), (229, 157, 95), (119, 64, 251), (0, 0, 0), (69, 248, 175)]
# Dominant colors in processed_0d3cf39f-78f1-440e-9504-f510e75aff0b.jpg: [(48, 47, 50), (251, 49, 46), (51, 251, 49), (46, 51, 251), (0, 0, 0)]
# Dominant colors in processed_0d639320-434a-469f-a9b7-d1f8e3b1f22a.jpg: [(1, 1, 1), (243, 113, 111), (98, 252, 102), (100, 98, 252), (101, 98, 96)]
# Dominant colors in processed_0d73e759-eeaa-43ab-98d4-196b6974c41e.jpg: [(138, 138, 145), (1, 1, 1), (148, 253, 141), (141, 149, 253), (253, 141, 141)]
# Dominant colors in processed_0d87a812-8c30-4b1f-9ecc-199ae426c8e6.jpg: [(68, 85, 117), (124, 251, 73), (0, 0, 0), (252, 73, 90), (129, 152, 239)]
# Dominant colors in processed_0d9f1bf9-0008-4247-b22b-832ab1c62a70.jpg: [(100, 252, 80), (2, 2, 3), (252, 80, 88), (90, 101, 250), (78, 86, 98)]
